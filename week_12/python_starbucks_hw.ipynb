# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
drinks_content = pd.read_csv('/Users/user/Documents/CodeClan/de13_classnotes/week_12/day_2/4_homework/data/starbucks_drinkMenu_expanded.csv')

# %%
drinks_content.head(5) #show the first 5 rows
# Out:
#               Beverage_category                                      Beverage  \
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
#           Beverage_prep  Calories  Total Fat (g)  Trans Fat (g)   \
# 237             Soymilk       320            3 2             0.4
# 238    Tall Nonfat Milk       170            0.1             0.1
# 239          Whole Milk       200            3.5             2.0
# 240             Soymilk       180            1.5             0.2
# 241  Grande Nonfat Milk       240            0.1             0.1
#
#      Saturated Fat (g)   Sodium (mg)   Total Carbohydrates (g)   \
# ...

# %%
drinks_content.tail(5) #show the last 5 rows
# Out:
#               Beverage_category                                      Beverage  \
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
#           Beverage_prep  Calories  Total Fat (g)  Trans Fat (g)   \
# 237             Soymilk       320            3 2             0.4
# 238    Tall Nonfat Milk       170            0.1             0.1
# 239          Whole Milk       200            3.5             2.0
# 240             Soymilk       180            1.5             0.2
# 241  Grande Nonfat Milk       240            0.1             0.1
#
#      Saturated Fat (g)   Sodium (mg)   Total Carbohydrates (g)   \
# ...

# %%
drinks_content.shape #show the dimensions of the dataframe (242 rows and 18 columns)
# Out:
# (242, 18)

# %%
drinks_content.columns #show the names of the columns
# Out:
# Index(['Beverage_category', 'Beverage', 'Beverage_prep', 'Calories',
#        ' Total Fat (g)', 'Trans Fat (g) ', 'Saturated Fat (g)', ' Sodium (mg)',
#        ' Total Carbohydrates (g) ', 'Cholesterol (mg)', ' Dietary Fibre (g)',
#        ' Sugars (g)', ' Protein (g) ', 'Vitamin A (% DV) ', 'Vitamin C (% DV)',
#        ' Calcium (% DV) ', 'Iron (% DV) ', 'Caffeine (mg)'],
#       dtype='object')

# %%
drinks_content.info() #show general info about column names, cells in each columns, data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Beverage_category          242 non-null    object
#  1   Beverage                   242 non-null    object
#  2   Beverage_prep              242 non-null    object
#  3   Calories                   242 non-null    int64
#  4    Total Fat (g)             242 non-null    object
#  5   Trans Fat (g)              242 non-null    float64
#  6   Saturated Fat (g)          242 non-null    float64
#  7    Sodium (mg)               242 non-null    int64
#  8    Total Carbohydrates (g)   242 non-null    int64
#  9   Cholesterol (mg)           242 non-null    int64
#  10   Dietary Fibre (g)         242 non-null    int64
#  11   Sugars (g)                242 non-null    int64
#  12   Protein (g)               242 non-null    float64
# ...

# %%
drinks_content.loc[[(drinks_content['Calories'].idxmin()),
                      (drinks_content['Calories'].idxmax())]]  # show the min and max number of calories per beverage
# Out:
#              Beverage_category                                       Beverage  \
# 102           Tazo® Tea Drinks                                      Tazo® Tea
# 84   Signature Espresso Drinks  White Chocolate Mocha (Without Whipped Cream)
#
#     Beverage_prep  Calories  Total Fat (g)  Trans Fat (g)   Saturated Fat (g)  \
# 102         Short         0              0             0.0                0.0
# 84        2% Milk       510             15             9.0                0.2
#
#       Sodium (mg)   Total Carbohydrates (g)   Cholesterol (mg)  \
# 102             0                          0                 0
# 84             35                        330                77
#
#       Dietary Fibre (g)   Sugars (g)   Protein (g)  Vitamin A (% DV)   \
# 102                   0            0            0.0                0%
# 84                    0           74           19.0               20%
#
#     Vitamin C (% DV)  Calcium (% DV)  Iron (% DV)  Caffeine (mg)
# ...

# %%
drinks_content['Calories'].describe()  #show summary statistics for the Calories column
# Out:
# count    242.000000
# mean     193.871901
# std      102.863303
# min        0.000000
# 25%      120.000000
# 50%      185.000000
# 75%      260.000000
# max      510.000000
# Name: Calories, dtype: float64

# %%
drinks = drinks_content[['Beverage_category', 'Beverage', 'Beverage_prep', 'Calories']].copy() 
#create a separate dataframe by selecting particular columns from the existing df

# %%
drinks
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
drinks.isna().sum() #check if there are any missing values
# Out:
# Beverage_category    0
# Beverage             0
# Beverage_prep        0
# Calories             0
# dtype: int64

# %%
drinks.loc[:, "calories_diff"] = 135 - drinks['Calories'] 
#create a new column that shows which drinks have more than 10 sugar cubes in them

# %%
drinks
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
ave_cal_drinks = drinks.groupby('Beverage_category')['Calories'].mean().reset_index(name = 'mean_calories').copy()
# create a column showing what the average number of calories is for each beverage category

# %%
drinks.loc[:,'Calories'].mean() # calculate the average number of calories across all drinks
# Out:
# 193.87190082644628

# %%
ave_cal_drinks.loc[:, "mean_calories_diff"] = drinks.loc[:,'Calories'].mean() - ave_cal_drinks['mean_calories']
# calculate the difference in average number of calories in each beverage category and the average number of calories 
# per all drinks

# %%
ave_cal_drinks
# Out:
#                    Beverage_category  mean_calories  mean_calories_diff
# 0            Classic Espresso Drinks     140.172414           53.699487
# 1                             Coffee       4.250000          189.621901
# 2        Frappuccino® Blended Coffee     276.944444          -83.072544
# 3         Frappuccino® Blended Crème     233.076923          -39.205022
# 4  Frappuccino® Light Blended Coffee     162.500000           31.371901
# 5              Shaken Iced Beverages     114.444444           79.427456
# 6          Signature Espresso Drinks     250.000000          -56.128099
# 7                          Smoothies     282.222222          -88.350321
# 8                   Tazo® Tea Drinks     177.307692           16.564209

# %%
drinks['Beverage_category'].unique() #check the unique values in the Beverage_category column
# Out:
# array(['Coffee', 'Classic Espresso Drinks', 'Signature Espresso Drinks',
#        'Tazo® Tea Drinks', 'Shaken Iced Beverages', 'Smoothies',
#        'Frappuccino® Blended Coffee', 'Frappuccino® Light Blended Coffee',
#        'Frappuccino® Blended Crème'], dtype=object)

# %%
drinks = drinks.loc[(drinks['Beverage_category'] != 'Tazo® Tea Drinks') &
                   (drinks['Beverage_category'] != 'Smoothies')].copy()
# filter the dataset leaving out drinks that don't contain coffee

# %%
drinks['Beverage_category'].unique() #check the line above worked
# Out:
# array(['Coffee', 'Classic Espresso Drinks', 'Signature Espresso Drinks',
#        'Shaken Iced Beverages', 'Frappuccino® Blended Coffee',
#        'Frappuccino® Light Blended Coffee', 'Frappuccino® Blended Crème'],
#       dtype=object)

# %%
drinks.sort_values('Calories', ascending = True) 
drinks.head() 
#arrange values in the Calories column starting from the lowest number of calories
# Out:
#          Beverage_category       Beverage      Beverage_prep  Calories  \
# 0                   Coffee  Brewed Coffee              Short         3
# 1                   Coffee  Brewed Coffee               Tall         4
# 2                   Coffee  Brewed Coffee             Grande         5
# 3                   Coffee  Brewed Coffee              Venti         5
# 4  Classic Espresso Drinks    Caffè Latte  Short Nonfat Milk        70
#
#    calories_diff
# 0            132
# 1            131
# 2            130
# 3            130
# 4             65

# %%
espresso_drinks = drinks.loc[(drinks['Beverage_category'] == 'Classic Espresso Drinks')].copy()
# filtering the dataset for the Classic Espresso Drinks within the beverage_category column

# %%
espresso_drinks.groupby('Beverage_prep')['Calories'].mean().reset_index(name = 'esp_mean_calories')
# calculating the average number of calories within Classic Espresso Drinks grouped by the Beverage_prep column
# Out:
#          Beverage_prep  esp_mean_calories
# 0              2% Milk            184.375
# 1               Doppio             10.000
# 2               Grande             15.000
# 3   Grande Nonfat Milk            150.000
# 4                Short              5.000
# 5    Short Nonfat Milk             78.000
# 6                 Solo              5.000
# 7              Soymilk            151.250
# 8                 Tall             10.000
# 9     Tall Nonfat Milk            116.000
# 10               Venti             25.000
# 11   Venti Nonfat Milk            194.000

# %%
espresso_drinks.groupby('Beverage_prep')['Calories'].mean().reset_index(name = 'esp_mean_calories').sort_values('esp_mean_calories', ascending = False)
# arranging the average number of calories in descending order
# Out:
#          Beverage_prep  esp_mean_calories
# 11   Venti Nonfat Milk            194.000
# 0              2% Milk            184.375
# 7              Soymilk            151.250
# 3   Grande Nonfat Milk            150.000
# 9     Tall Nonfat Milk            116.000
# 5    Short Nonfat Milk             78.000
# 10               Venti             25.000
# 2               Grande             15.000
# 1               Doppio             10.000
# 8                 Tall             10.000
# 4                Short              5.000
# 6                 Solo              5.000

# %%
type(espresso_drinks)
# Out:
# pandas.core.frame.DataFrame

# %%
esp_drinks_check = espresso_drinks.groupby('Beverage_prep')['Calories'].mean().reset_index(name = 'esp_mean_calories')

# %%
type(esp_drinks_check)
# Out:
# pandas.core.frame.DataFrame

# %%
drinks
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
sns.barplot(x = 'Calories',
            y = 'Beverage_category',
                color = 'red',
                #style = 'fertility_rate',
                data = drinks);

#plotting the number of calories based on beverage category
